# %% [markdown]
# # Pyber Challenge

# %% [markdown]
# ### 4.3 Loading and Reading CSV files

# %%
# Add Matplotlib inline magic command
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
from datetime import datetime
from matplotlib import style

# need for the date conversion to month on the chart
import matplotlib.dates as mdates

# File to Load (Remember to change these)
city_data_to_load = "resources/city_data.csv"
ride_data_to_load = "resources/ride_data.csv"

# Read the City and Ride Data
city_data_df = pd.read_csv(city_data_to_load)
ride_data_df = pd.read_csv(ride_data_to_load)

# %% [markdown]
# ### Merge the DataFrames

# %%
# Combine the data into a single dataset
pyber_data_df = pd.merge(ride_data_df, city_data_df, how="left", on=["city", "city"])

# Display the data table for preview
pyber_data_df
# Out:
#                     city                 date   fare        ride_id  \
# 0     Lake Jonathanshire  2019-01-14 10:14:22  13.83  5739410935873
# 1     South Michelleport  2019-03-04 18:24:09  30.24  2343912425577
# 2     Port Samanthamouth  2019-02-24 04:29:00  33.44  2005065760003
# 3             Rodneyfort  2019-02-10 23:22:03  23.44  5149245426178
# 4             South Jack  2019-03-06 04:28:35  34.58  3908451377344
# ...                  ...                  ...    ...            ...
# 2370         Michaelberg  2019-04-29 17:04:39  13.38  8550365057598
# 2371     Lake Latoyabury  2019-01-30 00:05:47  20.76  9018727594352
# 2372         North Jaime  2019-02-10 21:03:50  11.11  2781339863778
# 2373        West Heather  2019-05-07 19:22:15  44.94  4256853490277
# 2374          Newtonview  2019-04-25 10:20:13  55.84  9990581345298
#
#       driver_count   type
# 0                5  Urban
# 1               72  Urban
# 2               57  Urban
# 3               34  Urban
# ...

# %% [markdown]
# ## Deliverable 1: Get a Summary DataFrame

# %%
#  1. Get the total rides for each city type

total_ride_city = pyber_data_df.groupby(["type"]).count()["ride_id"]
total_ride_city.columns=["Total Rides"]

total_ride_city.head()
# Out:
# type
# Rural        125
# Suburban     625
# Urban       1625
# Name: ride_id, dtype: int64

# %%
# 2. Get the total drivers for each city type

# not sure if I had to use the pyber_data_df so I did

pyber_data_summary1 = pyber_data_df.groupby(["type" , "city"]).mean()["driver_count"]

total_driver_city= pyber_data_summary1.groupby(["type"]).sum()

#total_driver_city = pyber_data_df.groupby(["type"]).sum()["total_driver_city1"]

total_driver_city
# Out:
# type
# Rural         78.0
# Suburban     490.0
# Urban       2405.0
# Name: driver_count, dtype: float64

# %%
#  3. Get the total amount of fares for each city type
total_fare_city = pyber_data_df.groupby(["type"]).sum()["fare"]
total_fare_city
# Out:
# type
# Rural        4327.93
# Suburban    19356.33
# Urban       39854.38
# Name: fare, dtype: float64

# %%
#  4. Get the average fare per ride for each city type. 

ave_fare_city =  pyber_data_df.groupby(["type"]).mean()["fare"] 
ave_fare_city
# Out:
# type
# Rural       34.623440
# Suburban    30.970128
# Urban       24.525772
# Name: fare, dtype: float64

# %%
# 5. Get the average fare per driver for each city type.

ave_fare_driver =  total_fare_city / total_driver_city
ave_fare_driver.head()
# Out:
# type
# Rural       55.486282
# Suburban    39.502714
# Urban       16.571468
# dtype: float64

# %%
#  6. Create a PyBer summary DataFrame. 

pyber_summary_df = pd.concat([total_ride_city, total_driver_city, total_fare_city, ave_fare_city, ave_fare_driver], axis =1)

pyber_summary_df.columns = ["Total Rides", "Total Drivers", "Total Fares", "Average Fare per Ride", "Average Fare per Driver"]
pyber_summary_df
# Out:
#           Total Rides  Total Drivers  Total Fares  Average Fare per Ride  \
# type
# Rural             125           78.0      4327.93              34.623440
# Suburban          625          490.0     19356.33              30.970128
# Urban            1625         2405.0     39854.38              24.525772
#
#           Average Fare per Driver
# type
# Rural                   55.486282
# Suburban                39.502714
# Urban                   16.571468

# %%
#  7. Cleaning up the DataFrame. Delete the index name
pyber_summary_df.index.name = None

# %%
#  8. Format the columns.
pyber_summary_df['Total Rides'] = pyber_summary_df['Total Rides'].map('{:,.0f}'.format)
pyber_summary_df['Total Drivers'] = pyber_summary_df['Total Drivers'].map('{:,.0f}'.format)
pyber_summary_df['Total Fares'] = pyber_summary_df['Total Fares'].map('${:,.2f}'.format)
pyber_summary_df['Average Fare per Ride'] = pyber_summary_df['Average Fare per Ride'].map('${:,.2f}'.format)
pyber_summary_df['Average Fare per Driver'] = pyber_summary_df['Average Fare per Driver'].map('${:,.2f}'.format)
pyber_summary_df
# Out:
#          Total Rides Total Drivers Total Fares Average Fare per Ride  \
# Rural            125            78   $4,327.93                $34.62
# Suburban         625           490  $19,356.33                $30.97
# Urban          1,625         2,405  $39,854.38                $24.53
#
#          Average Fare per Driver
# Rural                     $55.49
# Suburban                  $39.50
# Urban                     $16.57

# %% [markdown]
# ## Deliverable 2.  Create a multiple line plot that shows the total weekly of the fares for each type of city.

# %%
# 1. Read the merged DataFrame
# the directions on the website don't match to the steps here. web site is showing I should by being doing the group by here.

pyber_data_df_new=pyber_data_df

# %%
# 2 1. Using groupby() to create a new DataFrame showing the sum of the fares 
#  for each date where the indices are the city type and date.

df=pyber_data_df_new.groupby(["type", "date"]).sum()["fare"]

df
# Out:
# type   date
# Rural  2019-01-01 09:45:36    43.69
#        2019-01-02 11:18:32    52.12
#        2019-01-03 19:51:01    19.90
#        2019-01-04 03:31:26    24.88
#        2019-01-06 07:38:40    47.33
#                               ...
# Urban  2019-05-08 04:20:00    21.99
#        2019-05-08 04:39:49    18.45
#        2019-05-08 07:29:01    18.55
#        2019-05-08 11:38:35    19.77
#        2019-05-08 13:10:18    18.04
# Name: fare, Length: 2375, dtype: float64

# %%
# 3 2. Reset the index on the DataFrame you created in #1. This is needed to use the 'pivot()' function.
df = df.reset_index()

# %%
# 4 3. Create a pivot table with the 'date' as the index, the columns ='type', and values='fare' 
# to get the total fares for each type of city by the date. 

df1=df.pivot_table(index =['date'], columns=['type'], values = 'fare')

df1
# Out:
# type                 Rural  Suburban  Urban
# date
# 2019-01-01 00:08:16    NaN       NaN  37.91
# 2019-01-01 00:46:46    NaN     47.74    NaN
# 2019-01-01 02:07:24    NaN     24.07    NaN
# 2019-01-01 03:46:50    NaN       NaN   7.57
# 2019-01-01 05:23:21    NaN       NaN  10.75
# ...                    ...       ...    ...
# 2019-05-08 04:20:00    NaN       NaN  21.99
# 2019-05-08 04:39:49    NaN       NaN  18.45
# 2019-05-08 07:29:01    NaN       NaN  18.55
# 2019-05-08 11:38:35    NaN       NaN  19.77
# 2019-05-08 13:10:18    NaN       NaN  18.04
#
# [2375 rows x 3 columns]

# %%
# 5. 4 Create a new DataFrame from the pivot table DataFrame using loc on the given dates, '2019-01-01':'2019-04-29'.

# create the DatFrame
df2=df1.reset_index()


# update the Date field
df2["date"] = pd.to_datetime(df2["date"])
#df2["date"] = df2['date'].dt.strftime('%Y-%m-%d')


# filter the DataFrame for dates
start = "2019-01-01"
end = "2019-04-29"

mask = (df2['date'] >= start) & (df2['date'] <=end)
df2=df2.loc[mask]

df2
# Out:
# type                date  Rural  Suburban  Urban
# 0    2019-01-01 00:08:16    NaN       NaN  37.91
# 1    2019-01-01 00:46:46    NaN     47.74    NaN
# 2    2019-01-01 02:07:24    NaN     24.07    NaN
# 3    2019-01-01 03:46:50    NaN       NaN   7.57
# 4    2019-01-01 05:23:21    NaN       NaN  10.75
# ...                  ...    ...       ...    ...
# 2191 2019-04-28 14:28:36    NaN       NaN  11.46
# 2192 2019-04-28 16:29:16    NaN       NaN  36.42
# 2193 2019-04-28 17:26:52    NaN       NaN  31.43
# 2194 2019-04-28 17:38:09    NaN     34.87    NaN
# 2195 2019-04-28 19:35:03    NaN     16.96    NaN
#
# [2196 rows x 4 columns]

# %%
# 6. Set the "date" index to datetime datatype. This is necessary to use the resample() method in Step 8.
# this become redunant as it is done in step 5.
#df2.index = pd.to_datetime(df2.index)
df2=df2.set_index("date")
df2
# Out:
# type                 Rural  Suburban  Urban
# date
# 2019-01-01 00:08:16    NaN       NaN  37.91
# 2019-01-01 00:46:46    NaN     47.74    NaN
# 2019-01-01 02:07:24    NaN     24.07    NaN
# 2019-01-01 03:46:50    NaN       NaN   7.57
# 2019-01-01 05:23:21    NaN       NaN  10.75
# ...                    ...       ...    ...
# 2019-04-28 14:28:36    NaN       NaN  11.46
# 2019-04-28 16:29:16    NaN       NaN  36.42
# 2019-04-28 17:26:52    NaN       NaN  31.43
# 2019-04-28 17:38:09    NaN     34.87    NaN
# 2019-04-28 19:35:03    NaN     16.96    NaN
#
# [2196 rows x 3 columns]

# %%
# 7. Check that the datatype for the index is datetime using df.info()

df2.info()


# good to go
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2196 entries, 2019-01-01 00:08:16 to 2019-04-28 19:35:03
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Rural     114 non-null    float64
#  1   Suburban  573 non-null    float64
#  2   Urban     1509 non-null   float64
# dtypes: float64(3)
# memory usage: 68.6 KB

# %%
# 8. Create a new DataFrame using the "resample()" function by week 'W' and get the sum of the fares for each week.

df_w = df2.resample("W", label="right").sum()


df_w
# Out:
# type         Rural  Suburban    Urban
# date
# 2019-01-06  187.92    721.60  1661.68
# 2019-01-13   67.65   1105.13  2050.43
# 2019-01-20  306.00   1218.20  1939.02
# 2019-01-27  179.69   1203.28  2129.51
# 2019-02-03  333.08   1042.79  2086.94
# 2019-02-10  115.80    974.34  2162.64
# 2019-02-17   95.82   1045.50  2235.07
# 2019-02-24  419.06   1412.74  2466.29
# 2019-03-03  175.14    858.46  2218.20
# 2019-03-10  303.94    925.27  2470.93
# 2019-03-17  163.39    906.20  2044.42
# 2019-03-24  189.76   1122.20  2368.37
# 2019-03-31  199.42   1045.06  1942.77
# 2019-04-07  501.24   1010.73  2356.70
# 2019-04-14  269.79    784.82  2390.72
# 2019-04-21  214.14   1149.27  2303.80
# 2019-04-28  191.85   1357.75  2238.29

# %%
# 8. Using the object-oriented interface method, plot the resample DataFrame using the df.plot() function. 

# the fig "figure" example The figure holds all of the artists.

# this block of code needs to be run twice. It looks like it is a bug with Jupyter and Python. Otherwise the 
# the style grid will not apply the first run through.



df4=df_w.reset_index()



# plot the figures
fig, ax=plt.subplots()

# Use the graph style fivethirtyeight.
plt.style.use('fivethirtyeight')
plt.grid(True)

x_axis=df4["date"]
y_axis1=df4["Urban"]
ax.plot(x_axis, y_axis1, color="gold", )

x_axis=df4["date"]
y_axis2=df4["Suburban"]
ax.plot(x_axis, y_axis2, color="red", )

x_axis=df4["date"]
y_axis3=df4["Rural"]
ax.plot(x_axis, y_axis3, color="blue", )


# labels
ax.set_title("Total Fare by City Type", fontsize=25)
ax.set_ylabel("Fare($USD)", fontsize=25)
ax.set_xlabel("2019",x=0)

#ax.legend(["Urban", "Suburban", "Rural"], title = "Type", loc="center", prop={'size':30})
ax.legend(["Urban", "Suburban", "Rural"], title = "Type", loc="center", fontsize = 25, title_fontsize = 25)

# Format the x axis to months. if there is a better way please let me know.

ax.xaxis.set_major_locator(mdates.MonthLocator(interval =1))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b'))

fig.set_size_inches(30, 10)
ax.set_ylim(0,2500)


plt.margins(x=0)


# Import the style from Matplotlib.
# I moved this to the beginning of the code



plt.show()
